# %% [markdown]
# <h1>Sommaire<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Un-peu-d'histoire-de-C" data-toc-modified-id="Un-peu-d'histoire-de-C-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Un peu d'histoire de C</a></span></li><li><span><a href="#Pourquoi-apprendre-C?" data-toc-modified-id="Pourquoi-apprendre-C?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Pourquoi apprendre C?</a></span></li><li><span><a href="#Exemple:-Hello-World" data-toc-modified-id="Exemple:-Hello-World-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exemple: Hello World</a></span></li><li><span><a href="#Comprendre-le-Hello-World" data-toc-modified-id="Comprendre-le-Hello-World-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Comprendre le Hello World</a></span><ul class="toc-item"><li><span><a href="#Bases-de-Syntaxe" data-toc-modified-id="Bases-de-Syntaxe-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Bases de Syntaxe</a></span></li><li><span><a href="#Commentaires" data-toc-modified-id="Commentaires-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Commentaires</a></span></li><li><span><a href="#Fonction:-main" data-toc-modified-id="Fonction:-main-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Fonction: main</a></span></li><li><span><a href="#Include" data-toc-modified-id="Include-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Include</a></span></li><li><span><a href="#Compiler" data-toc-modified-id="Compiler-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Compiler</a></span></li><li><span><a href="#Linker" data-toc-modified-id="Linker-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Linker</a></span></li></ul></li><li><span><a href="#Création-d'un-programme" data-toc-modified-id="Création-d'un-programme-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Création d'un programme</a></span><ul class="toc-item"><li><span><a href="#Mettre-en-place-un-terminal-et-un-éditeur" data-toc-modified-id="Mettre-en-place-un-terminal-et-un-éditeur-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Mettre en place un terminal et un éditeur</a></span></li><li><span><a href="#Organiser-son-travail-dans-un-répertoire" data-toc-modified-id="Organiser-son-travail-dans-un-répertoire-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Organiser son travail dans un répertoire</a></span></li><li><span><a href="#Editer-et-sauvegarder" data-toc-modified-id="Editer-et-sauvegarder-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Editer et sauvegarder</a></span></li><li><span><a href="#Compiler-et-executer" data-toc-modified-id="Compiler-et-executer-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Compiler et executer</a></span></li><li><span><a href="#Erreurs-et-Warnings-(IMPORTANT)" data-toc-modified-id="Erreurs-et-Warnings-(IMPORTANT)-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Erreurs et Warnings (IMPORTANT)</a></span></li><li><span><a href="#Pour-gagner-du-temps" data-toc-modified-id="Pour-gagner-du-temps-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Pour gagner du temps</a></span></li></ul></li><li><span><a href="#Exercice:-Bonjour" data-toc-modified-id="Exercice:-Bonjour-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Exercice: Bonjour</a></span></li></ul></div>

# %% [markdown]
# **Attention:** Pour activer le langage C, executer le code suivant avec `Shift-Entrée` où avec le bouton "Run".

# %%
# !pip install git+git://github.com/frehseg/gcc4jupyter
# %load_ext gcc_plugin
# Marche pas sur Google Colab: %load_ext add_cpp_magic

# %% [markdown]
# Pour tester si le plugin C marche, executez la cellule suivante: selectionnez-là et tapez `Shift-Entrée`. Si vous voyez le texte "Ca marche." apparaître en bas de la cellule, tout va bien.

# %%
# %%c
# #include <stdio.h>
# int main () {
#    printf("Ca marche.\n");
# }

# %% [markdown]
# **Attention:** La première ligne est "%%c" pour dire au Notebook que c'est un programme C. Cette ligne ne fait pas partie du programme!

# %% [markdown]
# # Un peu d'histoire de C
#
# - Voici Ken Thompson et Dennis Ritchie, chercheurs à Bell Labs en 1969
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/1/1b/Ken_Thompson_and_Dennis_Ritchie--1973.jpg" alt="Compilation" width = "30%" /></center>

# %% [markdown]
# - En 1969, ils avaient écrit le système d'exploitation Unix (précurseur de Linux) _en assembleur_ pour une PDP-7.
# - La galère : 4501 lignes de code assembleur.
# <center><img src="attachment:image.png" alt="Compilation" width = "50%" /></center>

# %% [markdown]
# - En 1970, ils étaient en charge de l'adapter pour la nouvelle PDP-11.
# - Tout était à refaire ...
# <center><img src="attachment:image.png" alt="PDP-11" width = "50%" /></center>

# %% [markdown]
# - Pour faciliter la tâche, ils ont crée un langage qui permet d'écrire un programme une fois et de le traduire (compiler) automatiquement sur n'importe quelle machine.
#
# <center><img src="https://www.emi.ac.ma/ntounsi/COURS/LogBase/Img/compilation.jpg" alt="Compilation" width = "50%" /></center>

# %% [markdown]
# - En 1972, ce langage est devenu C.
# - Depuis 1973, Unix / Linux est écrit en C, et fait aujourd'hui tourner une bonne majorité d'ordinateurs (smartphone,...).
# - Depuis 1988, la norme __POSIX__ (Portable Operating System Interface) garantit un environnement uniforme pour compiler et lancer des programmes en C.
# - compatible POSIX : MacOS, Linux, Android, iOS

# %% [markdown]
# # Pourquoi apprendre C?
# - classé no 1 ou 2 parmis les langages de programmation le plus utilisés depuis 30 ans.<br> Tiobe-Index:
# ![image.png](attachment:image.png)
# - très proche du matériel
# - fait comprendre comment marche un ordinateur
# - disponible sur n'importe quel ordinateur, du micro-onde jusqu'au supercalculateur
# - très rapide

# %% [markdown]
# # Exemple: Hello World
#
# Hello World: petit programme introduit par Dennis Ritchie dans son livre sur C, en 1978
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/The_C_Programming_Language%2C_First_Edition_Cover.svg/440px-The_C_Programming_Language%2C_First_Edition_Cover.svg.png" alt="K&R" width = "20%" /></center>

# %% [markdown]
# Voici le fameux programme "Hello World" en C:

# %%
# %%c
# #include <stdio.h>
# int main ()
# {
#    printf("Hello World !!\n");
#    return 0;
# }

# %% [markdown]
# Executer le code suivant avec `Shift-Entrée` où avec le bouton "Run":

# %%
# %%c
# /* Mon premier programme en C */
# #include <stdio.h>
# int main ()
# {
#    printf("Hello World !!\n");
#    return 0;
# }

# %% [markdown]
# # Comprendre le Hello World

# %% [markdown]
# Nous allons présenter la syntaxe (les réglès de forme) du langage C à l'exemple du programme "Hello World".

# %% [markdown]
# ## Bases de Syntaxe
# - chaque instruction est suivie d'un `;`
# - les espaces, tabulations, etc. n'ont aucune importance
#
# `printf ( "Hello" ) ;`
#
# `printf("Hello");`
#
# ```printf(   "Hello"
#              )
#         ;```

# %% [markdown]
# - définir un __bloc d'instructions__ avec `{`et `}`
#
# ```
# {
#    printf("Hello ");
#    printf("World.");
# }
# ```

# %% [markdown]
# ## Commentaires
#
# ```
# /* un commentaire...
#      ... sur plusieurs lignes ...
#           ... voilà.                */
#
# // commentaire sur une seule ligne
# ```
#
# Quand on écrit un programme, on __commence avec les commentaires!__

# %% [markdown]
# ## Fonction: main

# %% [markdown]
# Format d'une **fonction** :
#
# ...type de retour... `nom_de_fonction` `(` ... arguments ... `)` `{`
#
#     ... instructions ...
#
# `}`

# %% [markdown]
# Ici :
#
# `int` `main` `(`  `)` `{`
#
#     ... instructions ...
#
# `}`

# %% [markdown]
# Quand un programme est lancé, c'est la fonction `main` qui est appelé.

# %% [markdown]
# Une fonction peut donner une valeur de retour :<br>
#
# ...type de tour... `nom_de_fonction` `(` ... arguments ... `)` `{`<br>
# > ... instructions ... <br>
# > `return` ... valeur de retour ... `;`
#
# `}`

# %% [markdown]
# Dans le main, toujours:
# - type de retour: `int` (entier)
# - valeur de retour: `0` si tout va bien; autre valeur indique un problème

# %% [markdown]
# Exemple d'utilisation dans le shell: Afficher "ok" si tout va bien.
#
# ```./test1 && echo "ok"```

# %% [markdown]
# ## Include

# %% [markdown]
# `#include <stdio.h>`

# %% [markdown]
# Pour voir ce que ça fait, on l'enlève du programme en le passant en commentaire :
#
# `// #include <stdio.h>`

# %% [markdown]
# ```test1.c: In function ‘main’:
# test1.c:4:1: warning: implicit declaration of function ‘printf’ [-Wimplicit-function-declaration]
#  printf("Hello World !!\n");
#  ^~~~~~
# test1.c:4:1: warning: incompatible implicit declaration of built-in function ‘printf’
# test1.c:4:1: note: include ‘<stdio.h>’ or provide a declaration of ‘printf’
# ```

# %% [markdown]
# stdio.h déclare `printf`. On peut regarder le contenu de stdio.h, qui se trouve dans `/usr/include/stdio.h`...

# %% [markdown]
# ## Compiler
# Un programme s’écrit sous forme d’un texte ≪ source ≫. On utilise donc un éditeur de texte.
# Une fois écrit, il faut transformer ce texte en exécutable, c'est à dire dans une suite d'instructions connus au processeur. On utilise un **compilateur** C, dans ce cours ça sera le "GNU C Compiler" `gcc`. Dans un terminal :
#
#    ```gcc -Wall -Wfatal-errors monprogramme.c```
#
# Le fichier exécutable créée par défaut se nomme `a.out`.
# Vous pouvez alors exécuter votre programme en tapant dans un terminal :
#
#    ```./a.out```

# %% [markdown]
# ## Linker
# Des gros projets contiennent des milliers de fonctions et de millions de lignes de code. Tout ça c'est écrit par des équipes de plusieurs personnes.
#
# Pour mieux organiser le travail, les fonctions sont __distribués sur plusieurs fichiers__.
#
# Compiler le programme en entier peut durer plusieurs minutes, voir heures.
# On compile donc __un fichier de code à la fois__. Mais le compilateur doit connaître les fonctions données dans les autres fichiers...
#
# La solution c'est de __linker__ le code à la fin (édition de lien).

# %% [markdown]
# <center>
# <img src="https://www.emi.ac.ma/ntounsi/COURS/LogBase/Img/editionLien.jpg" alt="Linker" width="70%"/></center>

# %% [markdown]
# Regardons ce qui se passe si on n'a pas de fonction qui s'appelle `main`:

# %%
# %%c
# #include <stdio.h>
# int main2 ()
# {
#    printf("Hello World !!\n");
#    return 0;
# }

# %% [markdown]
# `ld` est le nom du linker. Il râle parce qu'il n'a pas trouvé de fonction "main". Pourtant, il en a besoin parce que c'est la fonction qui sera appelé quand on démarre le programme!

# %% [markdown]
# # Création d'un programme

# %% [markdown]
# ## Mettre en place un terminal et un éditeur
# 1. Démarrer Ubuntu VM... Terminal...
# 1. Ouvrir un Terminal, Super-Left pour l'afficher sur la gauche. (Super = Windows ou Command)
# 1. Ouvrir gedit (editeur de texte), Super-Right pour l'afficher sur la droite.
#
# On peut basculer entre terminal et editeur avec Super-Tab.

# %% [markdown]
# ## Organiser son travail dans un répertoire
# - créer le répertoire avec `mkdir cours1`
# - changer vers ce répertoire avec `cd cours1`

# %% [markdown]
# ## Editer et sauvegarder

# %% [markdown]
# On supposera que vous savez editer et sauvegarder des fichiers... En revanche, prenez l'habitude de *sauvegarder votre travail* (backup). C'est embêtant de perdre un programme sur lequel vous avez travaillé pendant deux heures, juste à la fin de l'examen (voir exemple en bas).
#
# Une solution rapide est de faire un zip de votre répertoire de temps en temps:
# ```
#    zip -r cours1_debut.zip cours1
# ```
# puis changez le nom de temps en temps:
# ```
#    zip -r cours1_moitie.zip cours1
# ```
# et
# ```
#    zip -r cours1_presque_fini.zip cours1
# ```
#
# **Attention:** Sans l'option `-r` votre zip contiendra un dossier vide!

# %% [markdown]
# ## Compiler et executer
# `gcc test.c`

# %% [markdown]
# La commande `ls` montre que le fichier `a.out` a été créé.

# %% [markdown]
# On l'execute avec
# `./a.out`
# parce que juste `a.out` ne cherche *pas* dans le répertoire courant (pour éviter toute ambiguité).

# %% [markdown]
# Pour changer le nom du fichier produit avec l'option `-o`.
# On peut récuperer la ligne précédente du terminal avec la flêche vers le haut, puis l'éditer.
#
# ```gcc -o test1 test1.c
# ls
# ./test1```

# %% [markdown]
# **Attention:** Une erreur courante est de taper trop vite et faire
#
# ```gcc -o test1.c test1
# ```
#
# C'est quoi le problème? Eh oui... le texte du programme qui était dans test1.c est perdu.

# %% [markdown]
# ## Erreurs et Warnings (IMPORTANT)
# Si le compilateur voit un problème avec votre programme, il produit des **warnings** (avertissements) et des messages d'**erreurs**.
# Pour les warnings, le compilateur ne s'arrête pas. Il est quand même fortement recommandé de les regarder et de les résoudre!
# Pour les erreurs, il faut savoir que seulement la première erreur compte. Tous les autres peuvent être un effet secondaire de la première erreur.
#
# Options du compilateur `gcc` essentielles:
# - `-Wall`: activer tous les avertissements
# - `-Werror`: traîter les warnings comme des erreurs
# - `-Wfatal-errors`: s'arrêter à la première erreur

# %% [markdown]
# ***
# **Imperatif pour ce cours:** Toujours utiliser les trois options essentielles!
#
# `gcc -Wall -Werror -Wfatal-errors test1.c`
# ***

# %% [markdown]
# ## Pour gagner du temps
#
# Si vous lancez la compilation depuis un terminal, vous n'êtes pas obligés de retaper les commandes à chaque fois.
# Il y a deux façons de réutiliser vos commandes précédentes:
# - **flèche vers le haut**: parcourt l'historique de toutes vos commandes
# - **`Ctrl-r` + texte**: cherche la dernière commande qui commence avec ce texte. Encore une fois `Ctrl-r`cherche l'avant-dernière etc.

# %% [markdown]
# # Exercice: Bonjour

# %% [markdown]
# Dans la cellule ci-dessous, écrivez un programme C qui affiche "Bonjour". Rappel: Pour executer le programme dans ce notebook, taper `Shift-Entré`.

# %%
/* Ecrivez le programme ici ...*/
